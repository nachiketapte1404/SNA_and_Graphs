# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-347863ab-46e9-493e-a308-effc99bf1daa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-347863ab-46e9-493e-a308-effc99bf1daa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_path = '/content/data.txt'

# %%
with open(file_path, 'r') as f:
    # Skip the first line which contains the counts
    next(f)

    # Add edges to the graph
    for line in f:
        source, target = map(int, line.split())
        G.add_edge(source, target)

# Run the PageRank algorithm
pagerank_scores = nx.pagerank(G)

# Print the PageRank scores for each node
for node, score in pagerank_scores.items():
    print(f'Node {node}: {score}')
# Out:
# Streaming output truncated to the last 5000 lines.
# Node 124560: 1.2920577737839557e-05
# Node 124131: 3.062265667327992e-06
# Node 124139: 8.879155592350101e-06
# Node 124288: 1.5166953913899563e-06
# Node 124141: 1.4941288810584289e-05
# Node 124310: 1.916866647232381e-05
# Node 124160: 8.879155592350101e-06
# Node 124149: 1.2259376074498087e-05
# Node 124144: 5.197925491870028e-06
# Node 124145: 7.308301720712382e-06
# Node 124294: 5.114670012465914e-06
# Node 124175: 1.2920577737839557e-05
# Node 124273: 6.490186496888774e-06
# Node 124170: 6.966988495815248e-06
# Node 124147: 1.089986666509483e-05
# Node 124239: 2.2559925126450288e-05
# Node 124159: 1.4022254731323253e-05
# Node 124182: 1.2786970594397384e-05
# Node 124157: 1.3034531474025311e-05
# Node 124181: 7.221949166642165e-06
# Node 124248: 9.33232539548452e-06
# Node 124246: 7.256035559945896e-06
# Node 124152: 6.414437767898988e-06
# Node 124161: 3.6997281756620703e-06
# Node 124535: 1.8183814960118516e-05
# ...

# %%
with open('pagerank_scores.txt', 'w') as output_file:
    for node, score in pagerank_scores.items():
        output_file.write(f'Node {node}: {score}\n')

# %%
# Sort the nodes by their PageRank scores in descending order
sorted_pagerank = sorted(pagerank_scores.items(), key=lambda x: x[1], reverse=True)

# Print the top 5 nodes with the highest PageRank scores
print("Top 5 nodes by PageRank:")
for i, (node, score) in enumerate(sorted_pagerank[:5], 1):
    print(f"{i}. Node {node}: {score}")
# Out:
# Top 5 nodes by PageRank:
# 1. Node 35862: 3.688644518398978e-05
# 2. Node 71574: 3.546023662777273e-05
# 3. Node 64335: 3.545162139249481e-05
# 4. Node 96592: 3.5383825171960184e-05
# 5. Node 70317: 3.5344292860363855e-05
